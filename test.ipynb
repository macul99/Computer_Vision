# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({'a': range(1, 11, 1), 'b': range(11, 21, 1)}, index=pd.date_range('2023-01-01', '2023-01-10', freq='D'))

# %%
df
# Out:
#              a   b
# 2023-01-01   1  11
# 2023-01-02   2  12
# 2023-01-03   3  13
# 2023-01-04   4  14
# 2023-01-05   5  15
# 2023-01-06   6  16
# 2023-01-07   7  17
# 2023-01-08   8  18
# 2023-01-09   9  19
# 2023-01-10  10  20

# %%
df.resample('2D', closed='right', label='right', offset='1D').apply(
   (np.max, np.min)
)
# Out:
# /tmp/ipykernel_741360/2523788217.py:1: FutureWarning: The provided callable <function max at 0x72c262698b80> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.resample('2D', closed='right', label='right', offset='1D').apply(
# /tmp/ipykernel_741360/2523788217.py:1: FutureWarning: The provided callable <function min at 0x72c262698ca0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.resample('2D', closed='right', label='right', offset='1D').apply(
#              a       b
#            max min max min
# 2023-01-02   2   1  12  11
# 2023-01-04   4   3  14  13
# 2023-01-06   6   5  16  15
# 2023-01-08   8   7  18  17
# 2023-01-10  10   9  20  19

# %%
df.resample('2D', closed='right', label='right', offset='1D').agg(
    lambda x: pd.Series({'a': x['a'].sum(), 'b_mean': x['b'].mean(), 'b_max': x['b'].max()})
)
# Out:
#                a  b_mean  b_max
# 2023-01-02   3.0    11.5   12.0
# 2023-01-04   7.0    13.5   14.0
# 2023-01-06  11.0    15.5   16.0
# 2023-01-08  15.0    17.5   18.0
# 2023-01-10  19.0    19.5   20.0

# %%
df.rolling(window=3, closed='both', center=True, ).agg(
    {'a': 'sum', 'b': 'mean'}
)
# Out:
#                a     b
# 2023-01-01   NaN   NaN
# 2023-01-02   6.0  12.0
# 2023-01-03  10.0  12.5
# 2023-01-04  14.0  13.5
# 2023-01-05  18.0  14.5
# 2023-01-06  22.0  15.5
# 2023-01-07  26.0  16.5
# 2023-01-08  30.0  17.5
# 2023-01-09  34.0  18.5
# 2023-01-10  27.0  19.0

# %%
df.shift(1, freq='D')
# Out:
#              a   b
# 2023-01-02   1  11
# 2023-01-03   2  12
# 2023-01-04   3  13
# 2023-01-05   4  14
# 2023-01-06   5  15
# 2023-01-07   6  16
# 2023-01-08   7  17
# 2023-01-09   8  18
# 2023-01-10   9  19
# 2023-01-11  10  20

# %%
df1 = df.copy()
df1['c'] = ['x', 'y'] * 5
df1
# Out:
#              a   b  c
# 2023-01-01   1  11  x
# 2023-01-02   2  12  y
# 2023-01-03   3  13  x
# 2023-01-04   4  14  y
# 2023-01-05   5  15  x
# 2023-01-06   6  16  y
# 2023-01-07   7  17  x
# 2023-01-08   8  18  y
# 2023-01-09   9  19  x
# 2023-01-10  10  20  y

# %%
df1.groupby('c').filter(
    lambda x: x['a'].sum() > 25,
    dropna=False
)
# Out:
#                a     b    c
# 2023-01-01   NaN   NaN  NaN
# 2023-01-02   2.0  12.0    y
# 2023-01-03   NaN   NaN  NaN
# 2023-01-04   4.0  14.0    y
# 2023-01-05   NaN   NaN  NaN
# 2023-01-06   6.0  16.0    y
# 2023-01-07   NaN   NaN  NaN
# 2023-01-08   8.0  18.0    y
# 2023-01-09   NaN   NaN  NaN
# 2023-01-10  10.0  20.0    y

# %%
df1.groupby('c').apply(
    lambda x: pd.DataFrame({
        'a': -1*x['a']
    })
)
# Out:
# /tmp/ipykernel_741360/913346061.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df1.groupby('c').apply(
#                a
# c
# x 2023-01-01  -1
#   2023-01-03  -3
#   2023-01-05  -5
#   2023-01-07  -7
#   2023-01-09  -9
# y 2023-01-02  -2
#   2023-01-04  -4
#   2023-01-06  -6
#   2023-01-08  -8
#   2023-01-10 -10

# %%
df1.head(1)
# Out:
#             a   b  c
# 2023-01-01  1  11  x

# %%
df1.groupby('c', group_keys=True).apply(lambda x: x)
# Out:
# /tmp/ipykernel_741360/2050792051.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df1.groupby('c', group_keys=True).apply(lambda x: x)
#                a   b  c
# c
# x 2023-01-01   1  11  x
#   2023-01-03   3  13  x
#   2023-01-05   5  15  x
#   2023-01-07   7  17  x
#   2023-01-09   9  19  x
# y 2023-01-02   2  12  y
#   2023-01-04   4  14  y
#   2023-01-06   6  16  y
#   2023-01-08   8  18  y
#   2023-01-10  10  20  y

# %%
grouped.get_group('x')

# %%
df.groupby('c').apply(lambda x: pd.DataFrame({'a': [x['a'].max(), x['a'].min()], 'b': [x['b'].max(), x['b'].min()]}, index=['max', 'min']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'b'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.apply(lambda x: x.idxmax())
# Out:
# a    c
# b    c
# c    b
# dtype: object

# %%
ds.to_frame()
# Out:
#    b
# 0  1
# 1  2
# 2  3

# %%
del df['a']

# %%
df
# Out:
#    b
# a  4
# b  5
# c  6

# %%
df.pop('b')
# Out:
# a    4
# b    5
# c    6
# Name: b, dtype: int64

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [a, b, c]

# %%
df['c'] = [7,8,9]
df
# Out:
#    c
# a  7
# b  8
# c  9

# %%
df.insert(0, 'd', [4,5,6])

# %%
df
# Out:
#    d  c
# a  4  7
# b  5  8
# c  6  9

# %%
df.assign(e=df['c'])
# Out:
#    d  c  e
# a  4  7  7
# b  5  8  8
# c  6  9  9

# %%
df
# Out:
#    d  c
# a  4  7
# b  5  8
# c  6  9

# %%
df.assign(x=lambda x: x['c'], y=lambda x: x['d'])
# Out:
#    d  c  x  y
# a  4  7  7  4
# b  5  8  8  5
# c  6  9  9  6

# %%
df.empty
# Out:
# False

# %%
df.rename(columns={'c': 'c1'}, index={'a':'a1'})
# Out:
#     d  c1
# a1  4   7
# b   5   8
# c   6   9

# %%
df.iloc[:2, :2]
# Out:
#    d  c
# a  4  7
# b  5  8

# %%
df.iat[0, 0]=9

# %%
df
# Out:
#    d  c
# a  9  7
# b  5  8
# c  6  9

# %%
df.loc['a':'b', 'd':'c']
# Out:
#    d  c
# a  9  7
# b  5  8

# %%
df.iloc[df.index.get_indexer(['a']), df.columns.get_indexer(['d'])]
# Out:
#    d
# a  9

# %%
df.columns.get_level_values(0)
# Out:
# Index(['d', 'c'], dtype='object')

# %%
df.loc[:, ('c',)]
# Out:
#    c
# a  7
# b  8
# c  9

# %%
df.convert_dtypes()
# Out:
#    d  c
# a  9  7
# b  5  8
# c  6  9

# %%
df.select_dtypes(include=['number'], exclude=['string'])
# Out:
#    d  c
# a  9  7
# b  5  8
# c  6  9

# %%
df.value_counts()
# Out:
# d  c
# 5  8    1
# 6  9    1
# 9  7    1
# Name: count, dtype: int64

# %%
df.sub(df['d'], axis=0)
# Out:
#    d  c
# a  0 -2
# b  0  3
# c  0  3

# %%
df.equals(df.copy())
# Out:
# True

# %%
import numpy as np
df.iat[0,0]=np.nan

# %%
df1=df.copy()
df1.fillna(3, inplace=True)

# %%
df.equals(df.copy())
# Out:
# True

# %%
df.combine_first(df1)
# Out:
#      d  c
# a  3.0  7
# b  5.0  8
# c  6.0  9

# %%
df
# Out:
#      d  c
# a  NaN  7
# b  5.0  8
# c  6.0  9

# %%
df.apply(lambda x: x.idxmax(), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.apply(lambda x: x.idxmax(), axis=1)
#
# NameError: name 'df' is not defined

# %%
df.apply({'d': "mean", "c": "sum"})
# Out:
# d     5.5
# c    24.0
# dtype: float64

# %%
df1.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_659619/2680973753.py in ?()
# ----> 1 df1.columns
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'
